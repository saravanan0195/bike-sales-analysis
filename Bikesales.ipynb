# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanan0195/bike-sales-analysis/blob/main/Bikesales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***A Bike Sales Dashboard*** that gives analysis depending on various factors.
#
#
#
# **Dataset**
#
#
# This dataset contains 1027 rows and 13 columns, in CSV format.
# The Marital Status column contains 2 kinds of values Married and Single.
# The Gender Column contains 2 kinds of values Female and Male.
# The Education column has various education levels,their occupation,income,age,whether they own a home or not and number of children.  The region they live in along with the commute distance (in miles) they traveled in order to purchase a bike.
# Based on the above factors and recorded data, here is the analysis of Bike Sales.

# %% [markdown]
# ![Maven upload.png](data:image/png;base64,...)
